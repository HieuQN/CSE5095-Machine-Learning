# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyen084/Logistic-Regression/blob/master/Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hieu Nguyen

# %% [markdown]
# Exercise 3: Soft Margin Linear Support Vector Machines
# 1. When $\xi^*_i=0$, the datapoints x^i is on the correct side of the boundary but within the margin.
# 2. The datapoint is on the wrong side of the boundary.

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
os.chdir(r'/content/gdrive/My Drive/Academic/UCONN/MATH5095Machine Learning/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC# load raw data
xdat = np.loadtxt('q1x.dat')
ydat = np.loadtxt('q1y.dat')

# define training data
# NOTE: In this exercise we are not measuring performance
# or performing model selection, so for demonstration purposes
# we will use all of the data for training and there is no test set.
X_train = xdat
y_train = ydat
# fit the linear Support Vector Classifier
clf = SVC(C=1, kernel='linear')
clf.fit(X_train, y_train)
# plot training data
fig, ax = plt.subplots()
ax.scatter(xdat[:,0], xdat[:,1], c=ydat, cmap='coolwarm')
ax.set(xlabel='x1', ylabel='x2')

# set ranges for plots
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1 = np.linspace(x1_min, x1_max)

# plot the decision boundary
w = clf.coef_[0]
b = clf.intercept_[0]
xx2 = (-w[0]/w[1])*xx1 - b/w[1]
ax.plot(xx1, xx2, 'k')

# circle the support vectors
sv = clf.support_vectors_
print('Number of support vectors:', sv.shape[0])
ax.scatter(sv[:,0], sv[:,1], s=100, facecolors='none', edgecolors='k')

# plot the margin
margin = 1/np.linalg.norm(w)
a = -w[0]/w[1]
xx2_down = xx2-np.sqrt(1+a**2)*margin
xx2_up = xx2+np.sqrt(1+a**2)*margin
ax.plot(xx1, xx2_down, 'k--')
ax.plot(xx1, xx2_up, 'k--')
# Out:
# Number of support vectors: 33

# %% [markdown]
# 3. hw2ex3-34 \
# a) In this python code clf = SVC(C=1, kernel='linear'), this means we are using Support vector classifier with soft margin with the C value of one, with linear kernel. Thus, the cost funtion of w we are minimizing is:
# $$ min\frac{1}{2}||w||^2_2 + \sum^m_{i=1}\xi_{i}$$
# b) Equation for decision boudary:
# $$y=\frac{w_0}{w_1}x-\frac{b}{w_1}$$
# c) Support vectors are the datapoints within the margin.

# %% [markdown]
# 4. a.The margin in this case is $\sum^{99}_{i=1}\xi_i$ \
# b. There are 33 support vectors. \
# c.

# %%
clf = SVC(C=10**-3, kernel='linear')
clf.fit(X_train, y_train)
# plot training data
fig, ax = plt.subplots()
ax.scatter(xdat[:,0], xdat[:,1], c=ydat, cmap='coolwarm')
ax.set(xlabel='x1', ylabel='x2')

# set ranges for plots
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1 = np.linspace(x1_min, x1_max)

# plot the decision boundary
w = clf.coef_[0]
b = clf.intercept_[0]
xx2 = (-w[0]/w[1])*xx1 - b/w[1]
ax.plot(xx1, xx2, 'k')

# circle the support vectors
sv = clf.support_vectors_
print('Number of support vectors:', sv.shape[0])
ax.scatter(sv[:,0], sv[:,1], s=100, facecolors='none', edgecolors='k')

# plot the margin
margin = 1/np.linalg.norm(w)
a = -w[0]/w[1]
xx2_down = xx2-np.sqrt(1+a**2)*margin
xx2_up = xx2+np.sqrt(1+a**2)*margin
ax.plot(xx1, xx2_down, 'k--')
ax.plot(xx1, xx2_up, 'k--')
# Out:
# Number of support vectors: 98

# %%
clf = SVC(C=10**6, kernel='linear')
clf.fit(X_train, y_train)
# plot training data
fig, ax = plt.subplots()
ax.scatter(xdat[:,0], xdat[:,1], c=ydat, cmap='coolwarm')
ax.set(xlabel='x1', ylabel='x2')

# set ranges for plots
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1 = np.linspace(x1_min, x1_max)

# plot the decision boundary
w = clf.coef_[0]
b = clf.intercept_[0]
xx2 = (-w[0]/w[1])*xx1 - b/w[1]
ax.plot(xx1, xx2, 'k')

# circle the support vectors
sv = clf.support_vectors_
print('Number of support vectors:', sv.shape[0])
ax.scatter(sv[:,0], sv[:,1], s=100, facecolors='none', edgecolors='k')

# plot the margin
margin = 1/np.linalg.norm(w)
a = -w[0]/w[1]
xx2_down = xx2-np.sqrt(1+a**2)*margin
xx2_up = xx2+np.sqrt(1+a**2)*margin
ax.plot(xx1, xx2_down, 'k--')
ax.plot(xx1, xx2_up, 'k--')
# Out:
# Number of support vectors: 28

# %%
clf = SVC(C=10**10, kernel='linear')
clf.fit(X_train, y_train)
# plot training data
fig, ax = plt.subplots()
ax.scatter(xdat[:,0], xdat[:,1], c=ydat, cmap='coolwarm')
ax.set(xlabel='x1', ylabel='x2')

# set ranges for plots
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1 = np.linspace(x1_min, x1_max)

# plot the decision boundary
w = clf.coef_[0]
b = clf.intercept_[0]
xx2 = (-w[0]/w[1])*xx1 - b/w[1]
ax.plot(xx1, xx2, 'k')

# circle the support vectors
sv = clf.support_vectors_
print('Number of support vectors:', sv.shape[0])
ax.scatter(sv[:,0], sv[:,1], s=100, facecolors='none', edgecolors='k')

# plot the margin
margin = 1/np.linalg.norm(w)
a = -w[0]/w[1]
xx2_down = xx2-np.sqrt(1+a**2)*margin
xx2_up = xx2+np.sqrt(1+a**2)*margin
ax.plot(xx1, xx2_down, 'k--')
ax.plot(xx1, xx2_up, 'k--')
# Out:
# Number of support vectors: 24

# %% [markdown]
# d. The margin gets smaller as C increases.

# %% [markdown]
# 5. hw2ex3-5

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import validation_curve
xdat = np.loadtxt('q1x.dat')
ydat = np.loadtxt('q1y.dat')
# use k-fold cross-validation to fit 
# the linear Support Vector Classifier
# for different values of C; performance
# metric is accuracy, which is the default
# score given by SVC()
clf = SVC(kernel='linear')
Clist = np.logspace(-4,6,num=6) # note we are using the default log base 10

# (Note: n_jobs has been added to speed up calculations via parallelization, 
# you may adjust this based on your processor or default to 1; 
# verbose has also been added to print out information while the function is running.
train_scores, valid_scores = validation_curve(clf, xdat, ydat, 'C', Clist, cv=10, n_jobs=4, verbose=1)
# compute the mean training and validation errors over k folds for each C
train_scores_mean = np.mean(train_scores, axis=1)
valid_scores_mean = np.mean(valid_scores, axis=1)
# plot training and validation error as a function of C
# (Note: the validation error is NOT the test error,
# which should be computed on a different test set after 
# model selection.)
fig, ax = plt.subplots()
ax.plot(Clist, 1-train_scores_mean, 'k-o', label='training')
ax.plot(Clist, 1-valid_scores_mean, 'r-o', label='validation')
ax.set(xlabel='C', ylabel='1-accuracy', xscale='log', ylim=[0,1], title='linear SVC')
ax.legend(loc='best')
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  60 out of  60 | elapsed:  1.2min finished

# %%
1-valid_scores_mean
# Out:
# array([0.49444444, 0.12222222, 0.12222222, 0.11222222, 0.11222222,
#        0.15444444])

# %% [markdown]
# a. From the above graph, we can use the C from $[10^{-4},1,10^2,10^4]$ to train out linear SVC it it gave similar validation error. \
# b. Due to the nature of this dataset, there is no C to get the training error to be 0 since the datapoints are not perfectly seperated. However, we can attempt to use different kernel function which maybe can help model the dataset beter.

# %% [markdown]
# Exercise 4. RBF kernel support vector Machines.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import validation_curve, GridSearchCV
from sklearn import datasets
# load and plot the famous moons dataset from sklearn
xdat, ydat = datasets.make_moons(n_samples=200, noise=0)
fig0, ax0 = plt.subplots()
ax0.scatter(xdat[:,0], xdat[:,1], c=1-ydat, cmap='coolwarm') # set color to c=1-ydat to reverse colors of the moons
ax0.set(xlabel='x1', ylabel='x2')
# explore classification using rbf kernel by varying hyperparameters
clf = SVC(C=1, kernel='rbf', gamma=1)
clf.fit(xdat, ydat)

# set ranges for plots
meshstep = 0.01
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, meshstep), np.arange(x2_min, x2_max, meshstep))

# plot the decision function, which is proportional to the distance from the decision boundary
# (lighter colors cover points closer to the decision boundary)
z = clf.decision_function(np.c_[xx1.ravel(), xx2.ravel()])
z = z.reshape(xx1.shape)
fig1, ax1 = plt.subplots()
ax1.scatter(xdat[:,0], xdat[:,1], c=1-ydat, cmap='coolwarm')
ax1.set(xlabel='x1', ylabel='x2')
ax1.contourf(xx1, xx2, z, cmap=plt.cm.RdBu, alpha=0.35)
## IN THE FOLLOWING SECTION, WE WILL TRAIN RBF KERNEL SVC USING FIXED C=1

# (Note: n_jobs has been added to speed up calculations via parallelization, 
# you may adjust this based on your processor or default to 1; 
# verbose has also been added to print out information while the function is running.)
clf_fixedC = SVC(C=1, kernel='rbf')
gammalist = np.logspace(-3,3,num=7)
train_scores, valid_scores = validation_curve(clf_fixedC, xdat, ydat, 'gamma', gammalist, cv=10, n_jobs=4, verbose=1)
# compute the mean training and validation errors over k folds for each gamma
train_scores_mean = np.mean(train_scores, axis=1)
valid_scores_mean = np.mean(valid_scores, axis=1)
# plot training and validation error as a function of gamma
fig2, ax2 = plt.subplots()
ax2.plot(gammalist, 1-train_scores_mean, 'k-o', label='training')
ax2.plot(gammalist, 1-valid_scores_mean, 'r-o', label='validation')
ax2.set(xlabel='gamma', ylabel='1-accuracy', xscale='log', ylim=[0,1], title='rbf kernel SVC')
ax2.legend(loc='best')
## IN THE FOLLOWING SECTION, WE WILL USE GRID SEARCH OVER C AND GAMMA, WITH 10-FOLD CV

# (Note: n_jobs has been added to speed up calculations via parallelization, 
# you may adjust this based on your processor or default to 1; 
# verbose has also been added to print out information while the function is running.)
Clist = np.logspace(-8,6,num=8)
gammalist = np.logspace(-3,3,num=7)
parameters = {'C':Clist, 'gamma':gammalist}
clf_gridsearch = GridSearchCV(SVC(kernel='rbf'), parameters, cv=10, n_jobs=4, verbose=1)
clf_gridsearch.fit(xdat, ydat)
# print the best hyperparameters and plot the heat map of validation errors
print("The best parameters are %s with a validation accuracy of %0.2f" % (clf_gridsearch.best_params_, clf_gridsearch.best_score_))

scores = clf_gridsearch.cv_results_['mean_test_score'].reshape(len(Clist),len(gammalist))
fig3, ax3 = plt.subplots()
currentimage = ax3.imshow(scores, cmap=plt.cm.hot)
ax3.set(xlabel='gamma', ylabel='C', title='validation accuracy')
fig3.colorbar(currentimage)
plt.xticks(np.arange(len(gammalist)), gammalist, rotation=45)
plt.yticks(np.arange(len(Clist)), Clist)
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  70 out of  70 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 10 folds for each of 56 candidates, totalling 560 fits
# [Parallel(n_jobs=4)]: Done 312 tasks      | elapsed:    0.8s
# The best parameters are {'C': 1e-08, 'gamma': 10.0} with a validation accuracy of 1.00
# [Parallel(n_jobs=4)]: Done 560 out of 560 | elapsed:    1.8s finished
# ([<matplotlib.axis.YTick at 0x7fef10f10be0>,
#   <matplotlib.axis.YTick at 0x7fef10f01668>,
#   <matplotlib.axis.YTick at 0x7fef115f6f98>,
#   <matplotlib.axis.YTick at 0x7fef11e51b38>,
#   <matplotlib.axis.YTick at 0x7fef11e3a278>,
#   <matplotlib.axis.YTick at 0x7fef11e40160>,
#   <matplotlib.axis.YTick at 0x7fef11e405c0>,
#   <matplotlib.axis.YTick at 0x7fef11e40a58>],
#  [Text(0, 0, '1e-08'),
#   Text(0, 0, '1e-06'),
#   Text(0, 0, '0.0001'),
#   Text(0, 0, '0.01'),
#   Text(0, 0, '1.0'),
#   Text(0, 0, '100.0'),
#   Text(0, 0, '10000.0'),
#   Text(0, 0, '1000000.0')])

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import validation_curve, GridSearchCV
from sklearn import datasets
# load and plot the famous moons dataset from sklearn
xdat, ydat = datasets.make_moons(n_samples=200, noise=0.25, random_state=2)
fig0, ax0 = plt.subplots()
ax0.scatter(xdat[:,0], xdat[:,1], c=1-ydat, cmap='coolwarm') # set color to c=1-ydat to reverse colors of the moons
ax0.set(xlabel='x1', ylabel='x2')
# explore classification using rbf kernel by varying hyperparameters
clf = SVC(C=1, kernel='rbf', gamma=100)
clf.fit(xdat, ydat)

# set ranges for plots
meshstep = 0.01
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, meshstep), np.arange(x2_min, x2_max, meshstep))

# plot the decision function, which is proportional to the distance from the decision boundary
# (lighter colors cover points closer to the decision boundary)
z = clf.decision_function(np.c_[xx1.ravel(), xx2.ravel()])
z = z.reshape(xx1.shape)
fig1, ax1 = plt.subplots()
ax1.scatter(xdat[:,0], xdat[:,1], c=1-ydat, cmap='coolwarm')
ax1.set(xlabel='x1', ylabel='x2')
ax1.contourf(xx1, xx2, z, cmap=plt.cm.RdBu, alpha=0.35)

# %%
## IN THE FOLLOWING SECTION, WE WILL TRAIN RBF KERNEL SVC USING FIXED C=1

# (Note: n_jobs has been added to speed up calculations via parallelization, 
# you may adjust this based on your processor or default to 1; 
# verbose has also been added to print out information while the function is running.)
clf_fixedC = SVC(C=1, kernel='rbf')
gammalist = np.logspace(-3,3,num=7)
train_scores, valid_scores = validation_curve(clf_fixedC, xdat, ydat, 'gamma', gammalist, cv=10, n_jobs=4, verbose=1)
# compute the mean training and validation errors over k folds for each gamma
train_scores_mean = np.mean(train_scores, axis=1)
valid_scores_mean = np.mean(valid_scores, axis=1)
# plot training and validation error as a function of gamma
fig2, ax2 = plt.subplots()
ax2.plot(gammalist, 1-train_scores_mean, 'k-o', label='training')
ax2.plot(gammalist, 1-valid_scores_mean, 'r-o', label='validation')
ax2.set(xlabel='gamma', ylabel='1-accuracy', xscale='log', ylim=[0,1], title='rbf kernel SVC')
ax2.legend(loc='best')
# Out:
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  70 out of  70 | elapsed:    1.9s finished

# %%
## IN THE FOLLOWING SECTION, WE WILL USE GRID SEARCH OVER C AND GAMMA, WITH 10-FOLD CV

# (Note: n_jobs has been added to speed up calculations via parallelization, 
# you may adjust this based on your processor or default to 1; 
# verbose has also been added to print out information while the function is running.)
Clist = np.logspace(-8,6,num=8)
gammalist = np.logspace(-3,3,num=7)
parameters = {'C':Clist, 'gamma':gammalist}
clf_gridsearch = GridSearchCV(SVC(kernel='rbf'), parameters, cv=10, n_jobs=4, verbose=1)
clf_gridsearch.fit(xdat, ydat)
# print the best hyperparameters and plot the heat map of validation errors
print("The best parameters are %s with a validation accuracy of %0.2f" % (clf_gridsearch.best_params_, clf_gridsearch.best_score_))

scores = clf_gridsearch.cv_results_['mean_test_score'].reshape(len(Clist),len(gammalist))
fig3, ax3 = plt.subplots()
currentimage = ax3.imshow(scores, cmap=plt.cm.hot)
ax3.set(xlabel='gamma', ylabel='C', title='validation accuracy')
fig3.colorbar(currentimage)
plt.xticks(np.arange(len(gammalist)), gammalist, rotation=45)
plt.yticks(np.arange(len(Clist)), Clist)
# Out:
# Fitting 10 folds for each of 56 candidates, totalling 560 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed:    1.9s
# The best parameters are {'C': 1e-08, 'gamma': 10.0} with a validation accuracy of 0.93
# [Parallel(n_jobs=4)]: Done 560 out of 560 | elapsed:   11.6s finished
# ([<matplotlib.axis.YTick at 0x7fef106ec3c8>,
#   <matplotlib.axis.YTick at 0x7fef106ba898>,
#   <matplotlib.axis.YTick at 0x7fef106e80b8>,
#   <matplotlib.axis.YTick at 0x7fef10643a90>,
#   <matplotlib.axis.YTick at 0x7fef10643f28>,
#   <matplotlib.axis.YTick at 0x7fef10640400>,
#   <matplotlib.axis.YTick at 0x7fef10640898>,
#   <matplotlib.axis.YTick at 0x7fef10640d30>],
#  [Text(0, 0, '1e-08'),
#   Text(0, 0, '1e-06'),
#   Text(0, 0, '0.0001'),
#   Text(0, 0, '0.01'),
#   Text(0, 0, '1.0'),
#   Text(0, 0, '100.0'),
#   Text(0, 0, '10000.0'),
#   Text(0, 0, '1000000.0')])

# %% [markdown]
# 2. Excluding the RBF kernel parameter, there are 2 hyperparameter which are regularization parameter,  and kernel coefiicient gamma scale. Fixing the regularization parameter, we can see that as gamma value incease, the training error would decreases which suggest that the model trying to best fit the datapoints.
# As for the decision boundary, as C and gamma increases, the decision boundary is more details and trying to best fit the training set.

# %% [markdown]
# 3. The optimal value of gamma is 10.

# %% [markdown]
# 4. In this case, there is is gamma such that the training error can be 0. As gamma is too large, the radius of the area of influence of the support vectors only includes the support vector itself such that the training dataset is perfectly seperated.

# %% [markdown]
# 5. The best parameters are {'C': 1e-08, 'gamma': 10.0} with a validation accuracy of 0.93. The plot for the decision functoin for the model trained below makes sense as the datapoints are in good cluster of decision boundary.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import validation_curve, GridSearchCV
from sklearn import datasets
# load and plot the famous moons dataset from sklearn
xdat, ydat = datasets.make_moons(n_samples=200, noise=0.25, random_state=2)
fig0, ax0 = plt.subplots()
ax0.scatter(xdat[:,0], xdat[:,1], c=1-ydat, cmap='coolwarm') # set color to c=1-ydat to reverse colors of the moons
ax0.set(xlabel='x1', ylabel='x2')
# explore classification using rbf kernel by varying hyperparameters
clf = SVC(C=10**-8, kernel='rbf', gamma=10)
clf.fit(xdat, ydat)

# set ranges for plots
meshstep = 0.01
x1_min, x1_max = xdat[:,0].min() - .5, xdat[:,0].max() + .5
x2_min, x2_max = xdat[:,1].min() - .5, xdat[:,1].max() + .5
xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, meshstep), np.arange(x2_min, x2_max, meshstep))

# plot the decision function, which is proportional to the distance from the decision boundary
# (lighter colors cover points closer to the decision boundary)
z = clf.decision_function(np.c_[xx1.ravel(), xx2.ravel()])
z = z.reshape(xx1.shape)
fig1, ax1 = plt.subplots()
ax1.scatter(xdat[:,0], xdat[:,1], c=1-ydat, cmap='coolwarm')
ax1.set(xlabel='x1', ylabel='x2')
ax1.contourf(xx1, xx2, z, cmap=plt.cm.RdBu, alpha=0.35)
